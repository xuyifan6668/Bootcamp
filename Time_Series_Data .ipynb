# %%
# %%capture
# !pip install statsforecast

# %%
##########
import os
import pandas as pd
import numpy as np
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from scipy.stats import norm
from statsforecast import StatsForecast
from statsforecast.models import (
    HoltWinters,
    CrostonClassic as Croston,
    HistoricAverage,
    DynamicOptimizedTheta as DOT,
    SeasonalNaive,
    AutoARIMA
)
from utilsforecast.losses import mse
from utilsforecast.evaluation import evaluate

# Set environment variable
os.environ['NIXTLA_ID_AS_COL'] = '1'

##########
# Read the data
df = pd.read_csv("https://github.com/xuyifan6668/Bootcamp/raw/main/energydata_complete.csv")

# %%
df.head()
# Out:
#                      Appliances  lights     T1       RH_1    T2       RH_2  \
# date
# 2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#                         T3       RH_3         T4       RH_4  ...         T9  \
# date                                                         ...
# 2016-01-11 17:00:00  19.79  44.730000  19.000000  45.566667  ...  17.033333
# 2016-01-11 17:10:00  19.79  44.790000  19.000000  45.992500  ...  17.066667
# 2016-01-11 17:20:00  19.79  44.933333  18.926667  45.890000  ...  17.000000
# 2016-01-11 17:30:00  19.79  45.000000  18.890000  45.723333  ...  17.000000
# ...

# %%
df.set_index("date", inplace=True)
# Out:
#                      Appliances  lights         T1       RH_1         T2  \
# date
# 2016-01-11 17:00:00          60      30  19.890000  47.596667  19.200000
# 2016-01-11 17:10:00          60      30  19.890000  46.693333  19.200000
# 2016-01-11 17:20:00          50      30  19.890000  46.300000  19.200000
# 2016-01-11 17:30:00          50      40  19.890000  46.066667  19.200000
# 2016-01-11 17:40:00          60      40  19.890000  46.333333  19.200000
# ...                         ...     ...        ...        ...        ...
# 2016-05-27 17:20:00         100       0  25.566667  46.560000  25.890000
# 2016-05-27 17:30:00          90       0  25.500000  46.500000  25.754000
# 2016-05-27 17:40:00         270      10  25.500000  46.596667  25.628571
# 2016-05-27 17:50:00         420      10  25.500000  46.990000  25.414000
# 2016-05-27 18:00:00         430      10  25.500000  46.600000  25.264286
#
#                           RH_2         T3       RH_3         T4       RH_4  \
# date
# ...

# %%
df = df.stack().reset_index().rename(columns={"date":"ds", "level_1":"unique_id", 0:'y'})[["unique_id", "ds", "y"]].sort_values(["unique_id","ds"]).reset_index(drop=True)

# %%
df['ds'] = pd.to_datetime(df['ds'])

# %%
df=df.groupby('unique_id').apply(lambda x: x.resample('H', on='ds').last())

# %%
df = df.drop(columns='unique_id').reset_index()

# %%
df.head()
# Out:
#     unique_id                  ds      y
# 0  Appliances 2016-01-11 17:00:00   50.0
# 1  Appliances 2016-01-11 18:00:00  580.0
# 2  Appliances 2016-01-11 19:00:00   70.0
# 3  Appliances 2016-01-11 20:00:00  110.0
# 4  Appliances 2016-01-11 21:00:00  100.0
